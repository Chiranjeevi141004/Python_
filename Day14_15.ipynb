# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiranjeevi141004/Python_Basics/blob/main/Day14_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
df = sns.get_dataset_names()

# %%
df
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
a = sns.load_dataset('taxis')

# %%
a
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sns.barplot(x='payment',y='total',data=a,color='blue',estimator='var')
plt.show()
plt.tight_layout()

# %%
sns.histplot(x=a['fare'],color='orange')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(x=a['fare'],palette=['blue','red'],hue=a['payment'])
plt.show()

# %%
b = sns.load_dataset('iris')

# %%
b
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(x=b['sepal_length'],color = 'black')
# Out:
# <Axes: xlabel='sepal_length'>

# %%
lower_bound =q1-1.5(q3-q1)

upper_bound =q3+1.5(q3-q1)

# %%
sns.boxplot(x=a['fare'],color = 'black')
# Out:
# <Axes: xlabel='fare'>

# %%
sns.barplot(x='sepal_length',y='species',data=b,color='blue',estimator='var')
plt.show()
plt.tight_layout()

# %%
sns.distplot(x=a['fare'],hist=False,kde=True,color='red')
# Out:
# <Axes: ylabel='Density'>

# %%
import seaborn as sns

# %%
id = sns.load_dataset('iris')

# %%
id
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
sns.boxplot(x=id['sepal_width'],palette=['violet','red','lightgreen'],y = id['species'])
plt.show()
# Out:
# <ipython-input-10-9d61b9825daf>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=id['sepal_width'],palette=['violet','red','lightgreen'],y = id['species'])

# %%
sns.scatterplot(x=a['fare'],y=a['total'],hue=a['payment'],palette=['grey','black'])
# Out:
# <Axes: xlabel='fare', ylabel='total'>

# %%
sns.scatterplot(x=a['fare'],y=a['total'],palette=['yellow','red'])
# Out:
# <ipython-input-13-56a1795baf44>:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x=a['fare'],y=a['total'],palette=['yellow','red'])
# <Axes: xlabel='fare', ylabel='total'>

# %%
sns.stripplot(x=a['fare'],y=a['payment'],palette=['blue','red'],hue=a['color'])
# Out:
# <Axes: xlabel='fare', ylabel='payment'>

# %%
sns.stripplot(x=a['fare'],y=a['payment'])
# Out:
# <Axes: xlabel='fare', ylabel='payment'>

# %%
sns.swarmplot(x=a['fare'],y=a['payment'],hue=a['color'],palette=['yellow','red'])
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 82.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 71.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='fare', ylabel='payment'>
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 89.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 81.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.lineplot(x=a['fare'],y=a['payment'])
# Out:
# <Axes: xlabel='fare', ylabel='payment'>

# %%
sns.lineplot(x=a['total'],y=a['fare'],hue=a['payment'],palette=['yellow','red'])
# Out:
# <Axes: xlabel='total', ylabel='fare'>

# %%
sns.countplot(x=a['payment'])
# Out:
# <Axes: xlabel='payment', ylabel='count'>
