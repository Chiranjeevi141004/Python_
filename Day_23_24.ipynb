# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiranjeevi141004/Python_/blob/main/Day_23_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import statsmodels.formula.api as smf

# %%
import matplotlib.pyplot as plt

# %%
cars = pd.read_csv('/Cars.csv')

# %%
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.shape
# Out:
# (81, 5)

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
sns.distplot(cars['MPG'], kde=True, color='Lightgreen')
# Out:
# <ipython-input-21-0858bdd17071>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars['MPG'], kde=True, color='Lightgreen')
# <Axes: xlabel='MPG', ylabel='Density'>

# %%
sns.distplot(cars['HP'], kde=True, color='Aqua')
# Out:
# <ipython-input-22-f3da32afc106>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars['HP'], kde=True, color='Aqua')
# <Axes: xlabel='HP', ylabel='Density'>

# %%
sns.distplot(cars['VOL'], kde=True, color='Yellow')
# Out:
# <ipython-input-23-524128f763d5>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars['VOL'], kde=True, color='Yellow')
# <Axes: xlabel='VOL', ylabel='Density'>

# %%
sns.distplot(cars['SP'], kde=True, color='Blue')
# Out:
# <ipython-input-24-201b9dfffddf>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars['SP'], kde=True, color='Blue')
# <Axes: xlabel='SP', ylabel='Density'>

# %%
sns.distplot(cars['WT'], kde=True, color='Orange')
# Out:
# <ipython-input-25-2f10c1ae3873>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars['WT'], kde=True, color='Orange')
# <Axes: xlabel='WT', ylabel='Density'>

# %%
sns.boxplot(x=cars['HP'])
# Out:
# <Axes: xlabel='HP'>

# %%
sns.scatterplot(x=cars['MPG'], y=cars['HP'])
# Out:
# <Axes: xlabel='MPG', ylabel='HP'>

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
sns.heatmap(cars.corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(x=cars['HP'], y=cars['MPG'])
# Out:
# <Axes: xlabel='HP', ylabel='MPG'>

# %%
sns.scatterplot(x=cars['HP'], y=cars['VOL'])
# Out:
# <Axes: xlabel='HP', ylabel='VOL'>

# %%
sns.scatterplot(x=cars['HP'], y=cars['SP'])
# Out:
# <Axes: xlabel='HP', ylabel='SP'>

# %%
sns.scatterplot(x=cars['HP'], y=cars['WT'])
# Out:
# <Axes: xlabel='HP', ylabel='WT'>

# %%
sns.scatterplot(x=cars['VOL'], y=cars['SP'])
# Out:
# <Axes: xlabel='VOL', ylabel='SP'>

# %%
sns.scatterplot(x=cars['VOL'], y=cars['WT'])
# Out:
# <Axes: xlabel='VOL', ylabel='WT'>

# %%
sns.scatterplot(x=cars['SP'], y=cars['WT'])
# Out:
# <Axes: xlabel='SP', ylabel='WT'>
