# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiranjeevi141004/Python_/blob/main/Day21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/AD_sections/NewspaperData.csv")
data.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#             Newspaper    daily   sunday
# 0       Baltimore Sun  391.952  488.506
# 1        Boston Globe  516.981  798.298
# 2       Boston Herald  355.628  235.084
# 3  Charlotte Observer  238.555  299.451
# 4   Chicago Sun Times  537.780  559.093

# %%
data.isnull().sum()
# Out:
# Newspaper    0
# daily        0
# sunday       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Newspaper  34 non-null     object
#  1   daily      34 non-null     float64
#  2   sunday     34 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 948.0+ bytes

# %%
data.shape
# Out:
# (34, 3)

# %%
data.sample(10)
# Out:
#                   Newspaper     daily    sunday
# 13        Los Angeles Times  1164.388  1531.527
# 4         Chicago Sun Times   537.780   559.093
# 22    Philadelphia Inquirer   515.523   982.663
# 5           Chicago Tribune   733.775  1133.249
# 12  Los Angeles Daily  News   185.736   202.614
# 8       Des Moines Register   206.204   344.522
# 6       Cincinnati Enquirer   198.832   348.744
# 17      New York Daily News   781.796   983.240
# 23         Pittsburgh Press   220.465   557.000
# 24       Portland Oregonian   337.672   440.923

# %%
data.drop('Newspaper',axis=1).corr()
# Out:
#            daily    sunday
# daily   1.000000  0.958154
# sunday  0.958154  1.000000
